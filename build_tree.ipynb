# %%
import json
import os

from bs4 import BeautifulSoup
from bs4.element import NavigableString

from libedx import parse_xml_file
from libedx import parse_xml_file_refusive
from libedx import print_course
from libedx import extract_course_tree


containerdir = 'chefdata/Sample2'

course_list = json.load(open(os.path.join(containerdir,'course_list.json')))
course_list
# Out:
# {'title': 'HP LIFE Sample Courses',
#  'kind': 'HP LIFE couses listing',
#  'courses': [{'name': 'Success Mindset (English)',
#    'path': 'Success_Mindset_English',
#    'lang': 'en'},
#   {'name': '3D Printing (हिन्दी)', 'path': '3D_printing_Hindi', 'lang': 'hi'},
#   {'name': 'Cash flow (中文)', 'path': 'Cash_flow_Chinese', 'lang': 'zh'},
#   {'name': '3D Printing (العربية)',
#    'path': 'Design_thinking_Arabic',
#    'lang': 'ar'}]}

# %%
course = course_list['courses'][0]
print('info from course_list json=', course)
basedir = os.path.join(containerdir, course['path'])
coursedir = os.path.join(basedir, 'course')
data = extract_course_tree(coursedir)
print_course(data)
# Out:
# info from course_list json= {'name': 'Success Mindset (English)', 'path': 'Success_Mindset_English', 'lang': 'en'}
#  - Success mindset kind=course 	  url_name=course attrs={'kind': 'course', 'display_name': 'Success mindset', 'enrollment_start': '"2018-10-11T00:00:00+00:00"', 'graceperiod': '', 'language': 'en', 'minimum_grade_credit': '0.8', 'start': '"2018-10-11T00:00:00+00:00"', 'url_name': 'course', 'org': 'hp-life-e-learning', 'course': '6638hpl-en30'}
#     - Start Course kind=chapter
#        - Success mindset kind=sequential
#           - Unit kind=vertical
#              -  kind=html 	  url_name=5e7e7ad5290f46cbbba0642d913f13c9
#     - Story kind=chapter
#        - Story Slides kind=sequential
#           - Unit kind=vertical
#              -  kind=problem 	 activity_ref=Success Mindset - Story
#     - Business Concept kind=chapter
#        - Activity kind=sequential
#           - Unit kind=vertical
#              -  kind=problem 	 activity_ref=Business Concept
#     - Technology Skill kind=chapter
#        - Activity kind=sequential
#           - Unit kind=vertical
#              -  kind=problem 	 activity_ref=Technology Skills
#        - Downloadable Resources kind=sequential
#           - Unit kind=vertical
#              -  kind=html 	  url_name=d51950e67be341ae98838f0d2ef9e867
#     - Course Feedback kind=chapter
#        - Survey kind=sequential
#           - Unit kind=vertical
#              -  kind=html 	  url_name=5f22d6fba0c34e1a9fb39516aa11c236
#              -  kind=html 	  url_name=bcd8654bff9f4a95b495fe423f1f4ffa
#     - Next Steps kind=chapter
#        - Next Steps kind=sequential
#           - Unit kind=vertical
#              -  kind=html 	  url_name=54bb0f81ef2e49edb274afa25ec72943
#     -  kind=wiki 	  slug=hp-life.2266hp-102.fall-2015

# %%
def flatten_subtree(chapter):
    """
    Returns a flat list of the content nodes
    """
    content_items = []
    for sequential in chapter['children']:
        for vertical in sequential['children']:
            for content_item in vertical['children']:
                content_item['title'] = sequential['display_name']
                content_items.append(content_item)
    return content_items

# %%
from le_utils.constants import content_kinds, file_types, licenses
from ricecooker.classes.licenses import get_license

from sushichef import transform_resource_folder
from sushichef import transform_html
from sushichef import transform_articulate_storyline_folder

HPLIFE_LICENSE = get_license(licenses.CC_BY, copyright_holder='HP LIFE').as_dict()






def build_subtree_from_course(course):
    print('Building a tree from course', course)
    course_dict = dict(
        title=course['name'],
        language=course['lang'],
        children = [],
    )
    basedir = os.path.join(containerdir, course['path'])
    contentdir = os.path.join(basedir, 'content')
    coursedir = os.path.join(basedir, 'course')
    data = extract_course_tree(coursedir)

    # TODO: title = data['display_name'] + (first_native_name)

    course_dict['source_id'] = data['course']


    for i, chapter in enumerate(data['children']):

        if 'display_name' not in chapter:
            print('skipping title-less wiki')
            continue
        if i == 4:
            print('skipping course feedback', chapter['display_name'])
            continue

        chapter_dict = dict(
            title=chapter['display_name'],
            source_id=chapter['display_name'],
            children = [],
        )
        course_dict['children'].append(chapter_dict)

        content_items = flatten_subtree(chapter)
        for item in content_items:
            html5_dict = dict(
                kind=content_kinds.HTML5,
                title=chapter_dict['title'],
                source_id=chapter_dict['title'],
                license=HPLIFE_LICENSE,
                language=course['lang'],
                files=[],
            )
            chapter_dict['children'].append(html5_dict)


            kind = item['kind']

            # Resouce folder
            if kind == 'html' and 'activity' in item:
                activity_ref = item['activity']['activity_ref']
                zip_info = transform_resource_folder(contentdir, activity_ref, item['content'])
                if zip_info:
                    zippath = zip_info['zippath']
                else:
                    continue

            # Generic HTML
            elif kind == 'html':
                zip_info = transform_html(item['content'])
                zippath = zip_info['zippath']

            # Articulate Storyline
            elif kind == 'problem' and 'activity' in item:
                activity_ref = item['activity']['activity_ref']
                zip_info = transform_articulate_storyline_folder(contentdir, activity_ref)
                if zip_info:
                    html5_dict['thumbnail'] = zip_info['thumbnail']
                    zippath = zip_info['zippath']
                else:
                    print('transform_articulate_storyline_folder returned None')
                    continue

            file_dict = dict(
                file_type=file_types.HTML5,
                path=zippath,
                language=course['lang'],
            )
            html5_dict['files'].append(file_dict)
        
    return course_dict



channel_dict = dict(    
    children = []
)

for course in course_list['courses']:
    course_dict = build_subtree_from_course(course)
    channel_dict['children'].append(course_dict)
# Out:
# Building a tree from course {'name': 'Success Mindset (English)', 'path': 'Success_Mindset_English', 'lang': 'en'}
# skipping course feedback Course Feedback
# skipping title-less wiki
# Building a tree from course {'name': '3D Printing (हिन्दी)', 'path': '3D_printing_Hindi', 'lang': 'hi'}
# Found resources_folder {'kind': 'resources_folder', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/3D+Printing+(Hindi)', 'activity_ref': 'Downloadable Resources', 'entrypoint': None}
# https://s3.amazonaws.com/hp-life-content/Antonio+TechClass+Academy/3D+Printing+(Hindi)/Downloadable+Resources/3D+printing+application+areas+HI.pdf
# https://s3.amazonaws.com/hp-life-content/Antonio+TechClass+Academy/3D+Printing+(Hindi)/Downloadable+Resources/3D+printing++marketplaces+-+services+-+resources+HI.pdf
# https://s3.amazonaws.com/hp-life-content/Antonio+TechClass+Academy/3D+Printing+(Hindi)/Downloadable+Resources/3D+printing+processes+and+technologies+HI.pdf
# https://s3.amazonaws.com/hp-life-content/Antonio+TechClass+Academy/3D+Printing+(Hindi)/Downloadable+Resources/3D+printing+materials+HI.pdf
# https://s3.amazonaws.com/hp-life-content/Antonio+TechClass+Academy/3D+Printing+(Hindi)/Downloadable+Resources/3D+printing+tips+HI.pdf
# https://s3.amazonaws.com/hp-life-content/Antonio+TechClass+Academy/3D+Printing+(Hindi)/Downloadable+Resources/3D+printing+tips+HI.pdf
# https://s3.amazonaws.com/hp-life-content/Antonio+TechClass+Academy/3D+Printing+(Hindi)/Downloadable+Resources/Water_Adapter_55_5.stl
# skipping course feedback सर्वेक्षण
# skipping title-less wiki
# Building a tree from course {'name': 'Cash flow (中文)', 'path': 'Cash_flow_Chinese', 'lang': 'zh'}
# Found unexpected problem type at chefdata/Sample2/Cash_flow_Chinese/course/problem/9253bf7559c344fdb0d5c816ef23f448.xml
# wrong guess about content type--- this is not an articulate_storyline_...
# transform_articulate_storyline_folder returned None
# skipping course feedback 调查
# skipping title-less wiki
# Building a tree from course {'name': '3D Printing (العربية)', 'path': 'Design_thinking_Arabic', 'lang': 'ar'}
# Found resources_folder {'kind': 'resources_folder', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Sweet_Rush/Design+Thinking/Arabic', 'activity_ref': 'Downloadables', 'entrypoint': None}
# missing sourcedir chefdata/Sample2/Design_thinking_Arabic/content/Downloadables
# skipping course feedback ردود فعل على الدورة التدريبية
# skipping title-less wiki

# %%
channel_dict
# Out:
# {'children': [{'title': 'Success Mindset (English)',
#    'language': 'en',
#    'children': [{'title': 'Start Course',
#      'source_id': 'Start Course',
#      'children': [{'kind': 'html5',
#        'title': 'Start Course',
#        'source_id': 'Start Course',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'en',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpm3q3vteu.zip',
#          'language': 'en'}]}]},
#     {'title': 'Story',
#      'source_id': 'Story',
#      'children': [{'kind': 'html5',
#        'title': 'Story',
#        'source_id': 'Story',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'en',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpf5qjocmr.zip',
#          'language': 'en'}],
#        'thumbnail': 'chefdata/Sample2/Success_Mindset_English/content/Success Mindset - Story_webroot/story_content/thumbnail.jpg'}]},
#     {'title': 'Business Concept',
#      'source_id': 'Business Concept',
#      'children': [{'kind': 'html5',
#        'title': 'Business Concept',
#        'source_id': 'Business Concept',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'en',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpmslzlof9.zip',
#          'language': 'en'}],
#        'thumbnail': 'chefdata/Sample2/Success_Mindset_English/content/Business Concept_webroot/story_content/thumbnail.jpg'}]},
#     {'title': 'Technology Skill',
#      'source_id': 'Technology Skill',
#      'children': [{'kind': 'html5',
#        'title': 'Technology Skill',
#        'source_id': 'Technology Skill',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'en',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpmhu1ygfv.zip',
#          'language': 'en'}],
#        'thumbnail': 'chefdata/Sample2/Success_Mindset_English/content/Technology Skills_webroot/story_content/thumbnail.jpg'},
#       {'kind': 'html5',
#        'title': 'Technology Skill',
#        'source_id': 'Technology Skill',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'en',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmp00way4x_.zip',
#          'language': 'en'}]}]},
#     {'title': 'Next Steps',
#      'source_id': 'Next Steps',
#      'children': [{'kind': 'html5',
#        'title': 'Next Steps',
#        'source_id': 'Next Steps',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'en',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmp_ok7ektd.zip',
#          'language': 'en'}]}]}],
#    'source_id': '6638hpl-en30'},
#   {'title': '3D Printing (हिन्दी)',
#    'language': 'hi',
#    'children': [{'title': 'प्रारंभ चक्र',
#      'source_id': 'प्रारंभ चक्र',
#      'children': [{'kind': 'html5',
#        'title': 'प्रारंभ चक्र',
#        'source_id': 'प्रारंभ चक्र',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'hi',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpy1qhboar.zip',
#          'language': 'hi'}]}]},
#     {'title': 'उदाहरण',
#      'source_id': 'उदाहरण',
#      'children': [{'kind': 'html5',
#        'title': 'उदाहरण',
#        'source_id': 'उदाहरण',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'hi',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpabd5lbaq.zip',
#          'language': 'hi'}],
#        'thumbnail': 'chefdata/Sample2/3D_printing_Hindi/content/29-3DP1-ST-HI-fix2_webroot/story_content/thumbnail.jpg'}]},
#     {'title': 'व्यापार की अवधारणा',
#      'source_id': 'व्यापार की अवधारणा',
#      'children': [{'kind': 'html5',
#        'title': 'व्यापार की अवधारणा',
#        'source_id': 'व्यापार की अवधारणा',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'hi',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpk4gsn6m2.zip',
#          'language': 'hi'}],
#        'thumbnail': 'chefdata/Sample2/3D_printing_Hindi/content/29-3DP2-BC-HI-fix2_webroot/story_content/thumbnail.jpg'}]},
#     {'title': 'प्रौद्योगिकी कौशल',
#      'source_id': 'प्रौद्योगिकी कौशल',
#      'children': [{'kind': 'html5',
#        'title': 'प्रौद्योगिकी कौशल',
#        'source_id': 'प्रौद्योगिकी कौशल',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'hi',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpqiv41prw.zip',
#          'language': 'hi'}],
#        'thumbnail': 'chefdata/Sample2/3D_printing_Hindi/content/29-3DP3-TS-HI-fix2_webroot/story_content/thumbnail.jpg'},
#       {'kind': 'html5',
#        'title': 'प्रौद्योगिकी कौशल',
#        'source_id': 'प्रौद्योगिकी कौशल',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'hi',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpginmxzw4.zip',
#          'language': 'hi'}]}]},
#     {'title': 'अगले चरण',
#      'source_id': 'अगले चरण',
#      'children': [{'kind': 'html5',
#        'title': 'अगले चरण',
#        'source_id': 'अगले चरण',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'hi',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpty2a6gjn.zip',
#          'language': 'hi'}]}]}],
#    'source_id': '6678hpl-hi29'},
#   {'title': 'Cash flow (中文)',
#    'language': 'zh',
#    'children': [{'title': '开始',
#      'source_id': '开始',
#      'children': [{'kind': 'html5',
#        'title': '开始',
#        'source_id': '开始',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'zh',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpd7_yadr2.zip',
#          'language': 'zh'}]}]},
#     {'title': '故事',
#      'source_id': '故事',
#      'children': [{'kind': 'html5',
#        'title': '故事',
#        'source_id': '故事',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'zh',
#        'files': []}]},
#     {'title': '经营理念',
#      'source_id': '经营理念',
#      'children': [{'kind': 'html5',
#        'title': '经营理念',
#        'source_id': '经营理念',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'zh',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpbokod_ax.zip',
#          'language': 'zh'}],
#        'thumbnail': 'chefdata/Sample2/Cash_flow_Chinese/content/CF_BC_CH1_webroot/story_content/thumbnail.jpg'}]},
#     {'title': '技术技能',
#      'source_id': '技术技能',
#      'children': [{'kind': 'html5',
#        'title': '技术技能',
#        'source_id': '技术技能',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'zh',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpozj9cxuh.zip',
#          'language': 'zh'}],
#        'thumbnail': 'chefdata/Sample2/Cash_flow_Chinese/content/CF_TS_CH2_webroot/story_content/thumbnail.jpg'},
#       {'kind': 'html5',
#        'title': '技术技能',
#        'source_id': '技术技能',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'zh',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpxr4_0ywg.zip',
#          'language': 'zh'}]}]},
#     {'title': '后续步骤',
#      'source_id': '后续步骤',
#      'children': [{'kind': 'html5',
#        'title': '后续步骤',
#        'source_id': '后续步骤',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'zh',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmp5u906um6.zip',
#          'language': 'zh'}]}]}],
#    'source_id': '2668hpl-zh16'},
#   {'title': '3D Printing (العربية)',
#    'language': 'ar',
#    'children': [{'title': 'البدء',
#      'source_id': 'البدء',
#      'children': [{'kind': 'html5',
#        'title': 'البدء',
#        'source_id': 'البدء',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'ar',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmp_qc26x0z.zip',
#          'language': 'ar'}]}]},
#     {'title': 'القصة',
#      'source_id': 'القصة',
#      'children': [{'kind': 'html5',
#        'title': 'القصة',
#        'source_id': 'القصة',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'ar',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpbndfz3u9.zip',
#          'language': 'ar'}],
#        'thumbnail': 'chefdata/Sample2/Design_thinking_Arabic/content/27-DT1-ST-AR-NR-MOB_webroot/story_content/thumbnail.jpg'}]},
#     {'title': 'مفهوم الأعمال',
#      'source_id': 'مفهوم الأعمال',
#      'children': [{'kind': 'html5',
#        'title': 'مفهوم الأعمال',
#        'source_id': 'مفهوم الأعمال',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'ar',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmp80vsluh_.zip',
#          'language': 'ar'}],
#        'thumbnail': 'chefdata/Sample2/Design_thinking_Arabic/content/27-DT2-BC-AR-NR-MOB_webroot/story_content/thumbnail.jpg'}]},
#     {'title': 'المهارات التَقنيَّة',
#      'source_id': 'المهارات التَقنيَّة',
#      'children': [{'kind': 'html5',
#        'title': 'المهارات التَقنيَّة',
#        'source_id': 'المهارات التَقنيَّة',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'ar',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmpt6z6xuch.zip',
#          'language': 'ar'}],
#        'thumbnail': 'chefdata/Sample2/Design_thinking_Arabic/content/27-DT3-TS-AR-NR-MOB_webroot/story_content/thumbnail.jpg'},
#       {'kind': 'html5',
#        'title': 'المهارات التَقنيَّة',
#        'source_id': 'المهارات التَقنيَّة',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'ar',
#        'files': []}]},
#     {'title': 'الخطوات التالية',
#      'source_id': 'الخطوات التالية',
#      'children': [{'kind': 'html5',
#        'title': 'الخطوات التالية',
#        'source_id': 'الخطوات التالية',
#        'license': {'license_id': 'CC BY',
#         'copyright_holder': 'HP LIFE',
#         'description': None},
#        'language': 'ar',
#        'files': [{'file_type': 'html5',
#          'path': '/var/folders/wc/2r44j8gs4gn56t1xtw5f6wlm0000gn/T/tmp7ilqk3dt.zip',
#          'language': 'ar'}]}]}],
#    'source_id': '4789hpl-ar27'}]}

# %%
doc = BeautifulSoup('<div><p>hello</p></div>', 'html5lib')

# %%
from bs4 import Tag
meta = Tag(name='meta', attrs={'charset':'utf-8'})
doc.head.append(meta)

# %%
doc
# Out:
# <html><head><meta charset="utf-8"></meta></head><body><div><p>hello</p></div></body></html>
