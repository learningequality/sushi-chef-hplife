# %%
import json
import os

from bs4 import BeautifulSoup
from bs4.element import NavigableString

from libedx import parse_xml_file
from libedx import parse_xml_file_refusive
from libedx import print_course
from libedx import extract_course_tree


containerdir = 'chefdata/Sample2'

course_list = json.load(open(os.path.join(containerdir,'course_list.json')))

# %%
course = course_list['courses'][1]
print('info from course_list json=', course)
basedir = os.path.join(containerdir, course['path'])
coursedir = os.path.join(basedir, 'course')
data = extract_course_tree(coursedir)
print_course(data)
# Out:
# info from course_list json= {'name': '3D Printing (हिन्दी)', 'path': '3D_printing_Hindi', 'lang': 'hi'}
# Found resources_folder {'kind': 'resources_folder', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/3D+Printing+(Hindi)', 'activity_ref': 'Downloadable+Resources', 'entrypoint': None}
#  - लाभ और हानि kind=course 	  url_name=course attrs={'kind': 'course', 'display_name': 'लाभ और हानि', 'enrollment_start': '"2015-10-27T00:00:00+00:00"', 'graceperiod': '', 'language': 'en', 'minimum_grade_credit': '0.8', 'start': '"2015-10-27T00:00:00+00:00"', 'url_name': 'course', 'org': 'hp-life-e-learning', 'course': '6678hpl-hi29'}
#     - प्रारंभ चक्र kind=chapter
#        - 3D प्रिंटिंग kind=sequential
#           - प्रारंभ kind=vertical
#              -  kind=html 	  url_name=8867e889c77c47878b3379ccca847cf5
#     - उदाहरण kind=chapter
#        - स्टोरी स्लाइडें kind=sequential
#           - यूनिट kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/3D+Printing+(Hindi)', 'activity_ref': '29-3DP1-ST-HI-fix2', 'entrypoint': 'story_html5.html'}
#     - व्यापार की अवधारणा kind=chapter
#        - गतिविधि kind=sequential
#           - यूनिट kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/3D+Printing+(Hindi)', 'activity_ref': '29-3DP2-BC-HI-fix2', 'entrypoint': 'story_html5.html'}
#     - प्रौद्योगिकी कौशल kind=chapter
#        - गतिविधि kind=sequential
#           - यूनिट kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/3D+Printing+(Hindi)', 'activity_ref': '29-3DP3-TS-HI-fix2', 'entrypoint': 'story_html5.html'}
#        - साधन kind=sequential
#           - तकनीकी कौशल संसाधनों kind=vertical
#              -  kind=html 	  url_name=41b35707a93b4b9eb3685a9183bef13factivity_ref={'kind': 'resources_folder', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/3D+Printing+(Hindi)', 'activity_ref': 'Downloadable+Resources', 'entrypoint': None}
#     - सर्वेक्षण kind=chapter
#        - पाठ्यक्रम प्रतिक्रिया kind=sequential
#           - यूनिट kind=vertical
#              -  kind=html 	  url_name=9dc0a57694804fba9387162d456d4653
#              -  kind=problem
#              -  kind=html 	  url_name=adda624c2240421a90b7d43eea4bc520
#     - अगले चरण kind=chapter
#        - अगले चरण kind=sequential
#           - यूनिट kind=vertical
#              -  kind=html 	  url_name=1ccef6cff975422f827d09b830bfe922
#     -  kind=wiki 	  slug=hp-life-e-learning.2388hpl-pt01.aberto

# %%
for course in course_list['courses']:
    print('info from course_list json=', course)
    basedir = os.path.join(containerdir, course['path'])
    coursedir = os.path.join(basedir, 'course')
    data = extract_course_tree(coursedir)
    print_course(data)
# Out:
# info from course_list json= {'name': 'Success Mindset (English)', 'path': 'Success_Mindset_English', 'lang': 'en'}
#  - Success mindset kind=course 	  url_name=course attrs={'kind': 'course', 'display_name': 'Success mindset', 'enrollment_start': '"2018-10-11T00:00:00+00:00"', 'graceperiod': '', 'language': 'en', 'minimum_grade_credit': '0.8', 'start': '"2018-10-11T00:00:00+00:00"', 'url_name': 'course', 'org': 'hp-life-e-learning', 'course': '6638hpl-en30'}
#     - Start Course kind=chapter
#        - Success mindset kind=sequential
#           - Unit kind=vertical
#              -  kind=html 	  url_name=5e7e7ad5290f46cbbba0642d913f13c9
#     - Story kind=chapter
#        - Story Slides kind=sequential
#           - Unit kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Sweet_Rush/Success+mindset', 'activity_ref': 'Success+Mindset+-+Story', 'entrypoint': 'story_html5.html'}
#     - Business Concept kind=chapter
#        - Activity kind=sequential
#           - Unit kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Sweet_Rush/Success+mindset/New+Files+-+14th+January+2019', 'activity_ref': 'Business+Concept', 'entrypoint': 'story_html5.html'}
#     - Technology Skill kind=chapter
#        - Activity kind=sequential
#           - Unit kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Sweet_Rush/Success+mindset/New+Files+-+14th+January+2019', 'activity_ref': 'Technology+Skills', 'entrypoint': 'story_html5.html'}
#        - Downloadable Resources kind=sequential
#           - Unit kind=vertical
#              -  kind=html 	  url_name=d51950e67be341ae98838f0d2ef9e867
#     - Course Feedback kind=chapter
#        - Survey kind=sequential
#           - Unit kind=vertical
#              -  kind=html 	  url_name=5f22d6fba0c34e1a9fb39516aa11c236
#              -  kind=problem
#              -  kind=html 	  url_name=bcd8654bff9f4a95b495fe423f1f4ffa
#     - Next Steps kind=chapter
#        - Next Steps kind=sequential
#           - Unit kind=vertical
#              -  kind=html 	  url_name=54bb0f81ef2e49edb274afa25ec72943
#     -  kind=wiki 	  slug=hp-life.2266hp-102.fall-2015
#
#
# info from course_list json= {'name': '3D Printing (हिन्दी)', 'path': '3D_printing_Hindi', 'lang': 'hi'}
# Found resources_folder {'kind': 'resources_folder', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/3D+Printing+(Hindi)', 'activity_ref': 'Downloadable+Resources', 'entrypoint': None}
#  - लाभ और हानि kind=course 	  url_name=course attrs={'kind': 'course', 'display_name': 'लाभ और हानि', 'enrollment_start': '"2015-10-27T00:00:00+00:00"', 'graceperiod': '', 'language': 'en', 'minimum_grade_credit': '0.8', 'start': '"2015-10-27T00:00:00+00:00"', 'url_name': 'course', 'org': 'hp-life-e-learning', 'course': '6678hpl-hi29'}
#     - प्रारंभ चक्र kind=chapter
#        - 3D प्रिंटिंग kind=sequential
#           - प्रारंभ kind=vertical
#              -  kind=html 	  url_name=8867e889c77c47878b3379ccca847cf5
#     - उदाहरण kind=chapter
#        - स्टोरी स्लाइडें kind=sequential
#           - यूनिट kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/3D+Printing+(Hindi)', 'activity_ref': '29-3DP1-ST-HI-fix2', 'entrypoint': 'story_html5.html'}
#     - व्यापार की अवधारणा kind=chapter
#        - गतिविधि kind=sequential
#           - यूनिट kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/3D+Printing+(Hindi)', 'activity_ref': '29-3DP2-BC-HI-fix2', 'entrypoint': 'story_html5.html'}
#     - प्रौद्योगिकी कौशल kind=chapter
#        - गतिविधि kind=sequential
#           - यूनिट kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/3D+Printing+(Hindi)', 'activity_ref': '29-3DP3-TS-HI-fix2', 'entrypoint': 'story_html5.html'}
#        - साधन kind=sequential
#           - तकनीकी कौशल संसाधनों kind=vertical
#              -  kind=html 	  url_name=41b35707a93b4b9eb3685a9183bef13factivity_ref={'kind': 'resources_folder', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/3D+Printing+(Hindi)', 'activity_ref': 'Downloadable+Resources', 'entrypoint': None}
#     - सर्वेक्षण kind=chapter
#        - पाठ्यक्रम प्रतिक्रिया kind=sequential
#           - यूनिट kind=vertical
#              -  kind=html 	  url_name=9dc0a57694804fba9387162d456d4653
#              -  kind=problem
#              -  kind=html 	  url_name=adda624c2240421a90b7d43eea4bc520
#     - अगले चरण kind=chapter
#        - अगले चरण kind=sequential
#           - यूनिट kind=vertical
#              -  kind=html 	  url_name=1ccef6cff975422f827d09b830bfe922
#     -  kind=wiki 	  slug=hp-life-e-learning.2388hpl-pt01.aberto
#
#
# info from course_list json= {'name': 'Cash flow (中文)', 'path': 'Cash_flow_Chinese', 'lang': 'zh'}
# Found unexpected problem type at chefdata/Sample2/Cash_flow_Chinese/course/problem/9253bf7559c344fdb0d5c816ef23f448.xml
#  - 现金流 kind=course 	  url_name=course attrs={'kind': 'course', 'display_name': '现金流', 'enrollment_start': '"2015-10-27T00:00:00+00:00"', 'graceperiod': '', 'language': 'en', 'minimum_grade_credit': '0.8', 'start': '"2015-10-27T00:00:00+00:00"', 'url_name': 'course', 'org': 'hp-life-e-learning', 'course': '2668hpl-zh16'}
#     - 开始 kind=chapter
#        - 现金流 kind=sequential
#           - 单元 kind=vertical
#              -  kind=html 	  url_name=21d69241c5b648319f85c033160b3b5d
#     - 故事 kind=chapter
#        - 案例幻灯片 kind=sequential
#           - 单元 kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://hpstoryline.edcastcloud.com/hp_storyline', 'bucket_path': '', 'activity_ref': 'hp_storyline', 'entrypoint': 'story?story=zh_16'}
#     - 经营理念 kind=chapter
#        - 活動 kind=sequential
#           - 单元 kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/Cash+Flow/Chinese', 'activity_ref': 'CF_BC_CH1', 'entrypoint': 'story_html5.html'}
#     - 技术技能 kind=chapter
#        - 活动 kind=sequential
#           - 单元 kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/Cash+Flow/Chinese', 'activity_ref': 'CF_TS_CH2', 'entrypoint': 'story_html5.html'}
#        - 可下載的資源 kind=sequential
#           - 单元 kind=vertical
#              -  kind=html 	  url_name=df775a7548c54f4facf9830f913a5cba
#     - 调查 kind=chapter
#        - 课程反馈 kind=sequential
#           - 单元 kind=vertical
#              -  kind=html 	  url_name=5953532f028448f28762d744dbb375e6
#              -  kind=problem
#     - 后续步骤 kind=chapter
#        - 后续步骤 kind=sequential
#           - 单元 kind=vertical
#              -  kind=html 	  url_name=b38018c1615743b0babae190ee3aa6e5
#     -  kind=wiki 	  slug=hp-life-e-learning.2545hpl-zh01.open
#
#
# info from course_list json= {'name': '3D Printing (العربية)', 'path': 'Design_thinking_Arabic', 'lang': 'ar'}
# Found resources_folder {'kind': 'resources_folder', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Sweet_Rush/Design+Thinking/Arabic', 'activity_ref': 'Downloadables', 'entrypoint': None}
#  - Design Thinking kind=course 	  url_name=course attrs={'kind': 'course', 'display_name': 'Design Thinking', 'enrollment_start': '"2017-01-23T00:00:00+00:00"', 'graceperiod': '', 'language': 'en', 'minimum_grade_credit': '0.8', 'start': '"2017-01-23T00:00:00+00:00"', 'url_name': 'course', 'org': 'hp-life-e-learning', 'course': '4789hpl-ar27'}
#     - البدء kind=chapter
#        - التفكير التصميمي kind=sequential
#           - Unit kind=vertical
#              -  kind=html 	  url_name=a7802ac001de430d9e1079f1e331a6ff
#     - القصة kind=chapter
#        - شرائح القصة kind=sequential
#           - Unit kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/Design+Thinking+(Mobile+friendly)/Arabic/27-DT-NR-MOB-AR/Publish', 'activity_ref': '27-DT1-ST-AR-NR-MOB', 'entrypoint': 'story_html5.html'}
#     - مفهوم الأعمال kind=chapter
#        - نشاط kind=sequential
#           - Unit kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/Design+Thinking+(Mobile+friendly)/Arabic/27-DT-NR-MOB-AR/Publish', 'activity_ref': '27-DT2-BC-AR-NR-MOB', 'entrypoint': 'story_html5.html'}
#     - المهارات التَقنيَّة kind=chapter
#        - نشاط kind=sequential
#           - Unit kind=vertical
#              -  kind=problem 	 activity_ref={'kind': 'articulate_storyline', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Antonio+TechClass+Academy/Design+Thinking+(Mobile+friendly)/Arabic/27-DT-NR-MOB-AR/Publish', 'activity_ref': '27-DT3-TS-AR-NR-MOB', 'entrypoint': 'story_html5.html'}
#        - الموارد للتحميل kind=sequential
#           - Unit kind=vertical
#              -  kind=html 	  url_name=80f9a0d108194af68402e96aa80015d1activity_ref={'kind': 'resources_folder', 'bucket_url': 'https://s3.amazonaws.com/hp-life-content', 'bucket_path': 'Sweet_Rush/Design+Thinking/Arabic', 'activity_ref': 'Downloadables', 'entrypoint': None}
#     - ردود فعل على الدورة التدريبية kind=chapter
#        - الاستطلاع kind=sequential
#           - Unit kind=vertical
#              -  kind=html 	  url_name=a89770c957b94d38a656d8cdc9d4b8d9
#              -  kind=problem
#              -  kind=html 	  url_name=236417739717464cb1bf7a735c38632f
#     - الخطوات التالية kind=chapter
#        - الخطوات التالية kind=sequential
#           - Unit kind=vertical
#              -  kind=html 	  url_name=b553969fcfe4401fb3353448060a0575
#     -  kind=wiki 	  slug=hp-life.2266hp-102.fall-2015
